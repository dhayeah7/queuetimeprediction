# %%
import numpy as np
import cv2
from ultralytics import YOLO
import supervision as sv
import pandas as pd

# Load YOLOv8 model
model = YOLO("yolov8n.pt")
box_annotator = sv.BoxAnnotator()

columns =['Person ID','Counter','Time taken']

df=pd.DataFrame(columns=columns)



# Define zones
zone_1 = np.array([[747, 622], [707, 38], [807, 22], [931, 654], [747, 622]])
zone_2 = np.array([[1039, 62], [1243, 546], [1271, 502], [1231, 286], [1107, 34], [1039, 62]])
zones = [zone_1, zone_2]
zone_annotator = sv.PolygonAnnotator()  # Assuming you have a PolygonAnnotator for zones
box_annotator = sv.BoxAnnotator()

tracker = sv.ByteTrack()  # ByteTrack tracker object
people_enter_queue = {}  # Dictionary to store entry times and zones
frame_count = 0
cap = cv2.VideoCapture("Retail.mp4")
def process_frame(frame: np.ndarray, i) -> np.ndarray:
    global frame_count

    
    results = model(frame)
    detections = sv.Detections.from_ultralytics(results[0])
    detections = detections[(detections.class_id == 0) & (detections.confidence > 0.5)]

    # Update tracker with detections
    detections = tracker.update_with_detections(detections)

    # Get the boxes and track IDs
    boxes = detections.xyxy
    track_ids = detections.tracker_id if isinstance(detections.tracker_id, np.ndarray) else np.array(detections.tracker_id)

    num_people_in_zone1 = 0
    num_people_in_zone2 = 0
    annotations = []

    for box, track_id in zip(boxes, track_ids):
        x1, y1, x2, y2 = map(int, box)
        x = (x1 + x2) / 2
        y = (y1 + y2) / 2

        in_zone_1 = cv2.pointPolygonTest(zone_1, (x, y), False) > 0
        in_zone_2 = cv2.pointPolygonTest(zone_2, (x, y), False) > 0

        if in_zone_1 or in_zone_2:
            if in_zone_1:
                num_people_in_zone1+=1
            else:
                num_people_in_zone2+=1
                   
            if str(track_id) not in people_enter_queue:
                people_enter_queue[str(track_id)] = {
                    'entry_frame': frame_count,
                    'zone': '1' if in_zone_1 else '2'
                }

            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
            
            entry_frame = people_enter_queue[str(track_id)]['entry_frame']
            time_spent = (frame_count - entry_frame) / cap.get(cv2.CAP_PROP_FPS)
            cv2.putText(frame, f"ID: {track_id}", (x1, y1 - 25), cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (0, 255, 0), 2)
            cv2.putText(frame, f"Time: {time_spent:.2f}s", (x1, y1 - 5), cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (0, 255, 0), 2)
            # zone = people_enter_queue[str(track_id)]['zone']
            # df.loc[len(df)]=[track_id,zone,time_spent]

        else:
            if str(track_id) in people_enter_queue:
                entry_frame = people_enter_queue[str(track_id)]['entry_frame']
                exit_frame = frame_count
                time_spent = (exit_frame - entry_frame) / cap.get(cv2.CAP_PROP_FPS)
                zone = people_enter_queue[str(track_id)]['zone']
                df.loc[len(df)]=[track_id,zone,time_spent]
                print(f"Person ID: {track_id} spent {time_spent:.2f} seconds in {zone}")
                
                del people_enter_queue[str(track_id)]

    # Annotate zones
    frame = box_annotator.annotate(frame.copy(), detections=detections)  
    cv2.putText(frame, f'People in counter 1: {num_people_in_zone1}', (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 
                1, (255, 255, 255), 2, cv2.LINE_AA)
    cv2.putText(frame, f'People in counter 2: {num_people_in_zone2}', (50, 100), cv2.FONT_HERSHEY_SIMPLEX, 
                1, (255, 255, 255), 2, cv2.LINE_AA) 

    frame_count += 1

    return frame

sv.process_video(
    source_path="Retail.mp4",
    target_path="result.mp4",
    callback=process_frame
)

df.to_csv('waittime.csv')
# Out:
# 0: 384x640 5 persons, 1 tv, 80.8ms
# Speed: 4.0ms preprocess, 80.8ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 tvs, 66.7ms
# Speed: 4.9ms preprocess, 66.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 tvs, 53.9ms
# Speed: 1.7ms preprocess, 53.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 tvs, 50.7ms
# Speed: 1.8ms preprocess, 50.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 61.9ms
# Speed: 1.7ms preprocess, 61.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 62.2ms
# Speed: 2.1ms preprocess, 62.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 90.7ms
# Speed: 3.5ms preprocess, 90.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 107.2ms
# Speed: 4.6ms preprocess, 107.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 82.7ms
# Speed: 4.0ms preprocess, 82.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 71.8ms
# Speed: 2.6ms preprocess, 71.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 70.7ms
# Speed: 2.8ms preprocess, 70.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 tv, 77.9ms
# Speed: 3.1ms preprocess, 77.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 68.4ms
# Speed: 3.0ms preprocess, 68.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 69.4ms
# Speed: 2.6ms preprocess, 69.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 66.9ms
# Speed: 2.5ms preprocess, 66.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 62.2ms
# Speed: 2.6ms preprocess, 62.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 68.3ms
# Speed: 2.9ms preprocess, 68.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 64.7ms
# Speed: 2.8ms preprocess, 64.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 67.2ms
# Speed: 2.7ms preprocess, 67.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 72.7ms
# Speed: 2.3ms preprocess, 72.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 67.8ms
# Speed: 3.1ms preprocess, 67.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 76.6ms
# Speed: 2.9ms preprocess, 76.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 72.5ms
# Speed: 3.0ms preprocess, 72.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 72.8ms
# Speed: 3.0ms preprocess, 72.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 72.0ms
# Speed: 2.6ms preprocess, 72.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 65.3ms
# Speed: 2.4ms preprocess, 65.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 79.8ms
# Speed: 3.0ms preprocess, 79.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 63.9ms
# Speed: 2.5ms preprocess, 63.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 68.8ms
# Speed: 2.7ms preprocess, 68.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 70.8ms
# Speed: 2.7ms preprocess, 70.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 1 laptop, 65.7ms
# Speed: 3.1ms preprocess, 65.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 66.6ms
# Speed: 2.4ms preprocess, 66.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 73.7ms
# Speed: 2.5ms preprocess, 73.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 1 laptop, 69.1ms
# Speed: 2.5ms preprocess, 69.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 74.1ms
# Speed: 2.8ms preprocess, 74.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 68.4ms
# Speed: 2.8ms preprocess, 68.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 1 laptop, 66.8ms
# Speed: 2.7ms preprocess, 66.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 laptop, 71.1ms
# Speed: 2.4ms preprocess, 71.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 laptop, 68.1ms
# Speed: 2.7ms preprocess, 68.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 65.5ms
# Speed: 3.2ms preprocess, 65.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 69.9ms
# Speed: 2.6ms preprocess, 69.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 78.0ms
# Speed: 2.6ms preprocess, 78.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 67.4ms
# Speed: 2.9ms preprocess, 67.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 67.1ms
# Speed: 2.7ms preprocess, 67.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 handbag, 1 tv, 65.1ms
# Speed: 4.0ms preprocess, 65.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 handbag, 1 tv, 1 laptop, 66.6ms
# Speed: 2.4ms preprocess, 66.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 handbag, 1 tv, 1 laptop, 67.4ms
# Speed: 2.2ms preprocess, 67.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 handbag, 2 tvs, 1 laptop, 65.7ms
# Speed: 2.8ms preprocess, 65.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 tvs, 1 laptop, 62.8ms
# Speed: 2.8ms preprocess, 62.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 tvs, 1 laptop, 62.8ms
# Speed: 2.4ms preprocess, 62.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 tvs, 2 laptops, 68.0ms
# Speed: 2.8ms preprocess, 68.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 2 laptops, 100.1ms
# Speed: 2.7ms preprocess, 100.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 tv, 2 laptops, 84.6ms
# Speed: 2.9ms preprocess, 84.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 2 laptops, 83.9ms
# Speed: 3.1ms preprocess, 83.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 2 laptops, 66.5ms
# Speed: 2.8ms preprocess, 66.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 2 laptops, 67.2ms
# Speed: 3.2ms preprocess, 67.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 4 laptops, 65.0ms
# Speed: 2.6ms preprocess, 65.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 4 laptops, 67.5ms
# Speed: 2.6ms preprocess, 67.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 tvs, 3 laptops, 67.1ms
# Speed: 2.5ms preprocess, 67.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 3 laptops, 66.7ms
# Speed: 3.2ms preprocess, 66.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 2 laptops, 67.1ms
# Speed: 3.1ms preprocess, 67.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 tvs, 1 laptop, 65.8ms
# Speed: 3.4ms preprocess, 65.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 tvs, 1 laptop, 76.7ms
# Speed: 2.8ms preprocess, 76.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 tvs, 1 laptop, 74.3ms
# Speed: 2.8ms preprocess, 74.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 tv, 1 laptop, 94.7ms
# Speed: 3.2ms preprocess, 94.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 tv, 1 laptop, 72.5ms
# Speed: 2.7ms preprocess, 72.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 tv, 1 laptop, 64.1ms
# Speed: 3.0ms preprocess, 64.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 tv, 1 laptop, 79.0ms
# Speed: 2.7ms preprocess, 79.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 tv, 2 laptops, 69.6ms
# Speed: 2.4ms preprocess, 69.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 tvs, 1 laptop, 241.3ms
# Speed: 3.1ms preprocess, 241.3ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 tvs, 1 laptop, 84.4ms
# Speed: 2.6ms preprocess, 84.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 tvs, 2 laptops, 98.7ms
# Speed: 4.7ms preprocess, 98.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 2 laptops, 120.3ms
# Speed: 3.9ms preprocess, 120.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 tvs, 1 laptop, 99.4ms
# Speed: 2.9ms preprocess, 99.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 tvs, 1 laptop, 89.8ms
# Speed: 2.7ms preprocess, 89.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 tvs, 1 laptop, 120.3ms
# Speed: 5.9ms preprocess, 120.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 handbag, 1 chair, 2 tvs, 1 laptop, 82.8ms
# Speed: 2.8ms preprocess, 82.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 handbag, 1 chair, 2 tvs, 168.8ms
# Speed: 3.9ms preprocess, 168.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 tvs, 110.7ms
# Speed: 4.0ms preprocess, 110.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 tvs, 87.9ms
# Speed: 3.7ms preprocess, 87.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 tvs, 83.9ms
# Speed: 2.9ms preprocess, 83.9ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 tvs, 1 laptop, 87.5ms
# Speed: 3.4ms preprocess, 87.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 tvs, 102.0ms
# Speed: 2.5ms preprocess, 102.0ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 tvs, 73.6ms
# Speed: 3.0ms preprocess, 73.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 tvs, 86.4ms
# Speed: 3.3ms preprocess, 86.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Person ID: 4 spent 5.60 seconds in 1
#
# 0: 384x640 5 persons, 3 tvs, 82.9ms
# Speed: 3.1ms preprocess, 82.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 handbag, 2 tvs, 75.0ms
# Speed: 2.8ms preprocess, 75.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 skateboard, 2 tvs, 75.5ms
# Speed: 2.7ms preprocess, 75.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 skateboards, 1 chair, 2 tvs, 73.3ms
# Speed: 3.2ms preprocess, 73.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 chair, 3 tvs, 69.4ms
# Speed: 2.7ms preprocess, 69.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 88.8ms
# Speed: 2.3ms preprocess, 88.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 98.3ms
# Speed: 2.5ms preprocess, 98.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 69.4ms
# Speed: 2.9ms preprocess, 69.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 123.5ms
# Speed: 3.6ms preprocess, 123.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 76.7ms
# Speed: 4.3ms preprocess, 76.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 tv, 77.3ms
# Speed: 2.6ms preprocess, 77.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 74.7ms
# Speed: 2.9ms preprocess, 74.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 74.6ms
# Speed: 2.3ms preprocess, 74.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 75.3ms
# Speed: 3.1ms preprocess, 75.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 68.2ms
# Speed: 2.7ms preprocess, 68.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 77.1ms
# Speed: 2.8ms preprocess, 77.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 68.8ms
# Speed: 2.7ms preprocess, 68.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 69.1ms
# Speed: 2.5ms preprocess, 69.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 tvs, 70.0ms
# Speed: 2.8ms preprocess, 70.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 82.0ms
# Speed: 2.9ms preprocess, 82.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 tvs, 1 laptop, 66.4ms
# Speed: 2.7ms preprocess, 66.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 76.6ms
# Speed: 2.4ms preprocess, 76.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 tvs, 71.5ms
# Speed: 3.1ms preprocess, 71.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 69.7ms
# Speed: 3.4ms preprocess, 69.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 73.7ms
# Speed: 3.1ms preprocess, 73.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 67.6ms
# Speed: 3.1ms preprocess, 67.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 tvs, 66.7ms
# Speed: 3.4ms preprocess, 66.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 1 laptop, 79.0ms
# Speed: 3.5ms preprocess, 79.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 1 laptop, 75.6ms
# Speed: 3.0ms preprocess, 75.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 laptop, 68.1ms
# Speed: 2.3ms preprocess, 68.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 umbrella, 1 tv, 68.7ms
# Speed: 2.7ms preprocess, 68.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 66.3ms
# Speed: 2.6ms preprocess, 66.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 86.7ms
# Speed: 2.5ms preprocess, 86.7ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 156.8ms
# Speed: 3.0ms preprocess, 156.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 77.7ms
# Speed: 3.3ms preprocess, 77.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 82.8ms
# Speed: 2.7ms preprocess, 82.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 71.4ms
# Speed: 2.9ms preprocess, 71.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 65.0ms
# Speed: 2.7ms preprocess, 65.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 chairs, 1 tv, 72.8ms
# Speed: 2.7ms preprocess, 72.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 tv, 69.9ms
# Speed: 3.4ms preprocess, 69.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 tv, 71.9ms
# Speed: 2.7ms preprocess, 71.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 73.8ms
# Speed: 3.0ms preprocess, 73.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 tvs, 78.3ms
# Speed: 2.7ms preprocess, 78.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 78.6ms
# Speed: 2.6ms preprocess, 78.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 1 laptop, 63.4ms
# Speed: 2.6ms preprocess, 63.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 1 laptop, 66.4ms
# Speed: 4.6ms preprocess, 66.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 1 laptop, 65.3ms
# Speed: 2.2ms preprocess, 65.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 1 laptop, 66.8ms
# Speed: 2.5ms preprocess, 66.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 1 laptop, 63.7ms
# Speed: 2.2ms preprocess, 63.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 1 laptop, 65.2ms
# Speed: 2.6ms preprocess, 65.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 65.5ms
# Speed: 3.8ms preprocess, 65.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 63.8ms
# Speed: 2.5ms preprocess, 63.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 67.5ms
# Speed: 2.8ms preprocess, 67.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 65.1ms
# Speed: 3.5ms preprocess, 65.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 61.9ms
# Speed: 2.3ms preprocess, 61.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 laptop, 65.2ms
# Speed: 2.4ms preprocess, 65.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 76.8ms
# Speed: 2.8ms preprocess, 76.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 69.0ms
# Speed: 2.5ms preprocess, 69.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 66.2ms
# Speed: 2.4ms preprocess, 66.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 63.8ms
# Speed: 3.2ms preprocess, 63.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 72.8ms
# Speed: 2.4ms preprocess, 72.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 63.7ms
# Speed: 2.7ms preprocess, 63.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 65.7ms
# Speed: 2.4ms preprocess, 65.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 63.8ms
# Speed: 2.9ms preprocess, 63.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 laptop, 76.4ms
# Speed: 3.0ms preprocess, 76.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 67.5ms
# Speed: 2.7ms preprocess, 67.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 67.6ms
# Speed: 3.2ms preprocess, 67.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 66.2ms
# Speed: 2.7ms preprocess, 66.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 1 laptop, 65.5ms
# Speed: 2.7ms preprocess, 65.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 1 laptop, 68.0ms
# Speed: 2.6ms preprocess, 68.0ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 1 laptop, 66.7ms
# Speed: 2.8ms preprocess, 66.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 1 laptop, 74.5ms
# Speed: 2.9ms preprocess, 74.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 1 laptop, 67.1ms
# Speed: 2.8ms preprocess, 67.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 laptop, 65.0ms
# Speed: 3.2ms preprocess, 65.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 114.7ms
# Speed: 2.4ms preprocess, 114.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 66.0ms
# Speed: 2.6ms preprocess, 66.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 laptop, 67.4ms
# Speed: 3.6ms preprocess, 67.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 laptop, 66.8ms
# Speed: 2.4ms preprocess, 66.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 laptop, 63.1ms
# Speed: 2.4ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 laptop, 65.1ms
# Speed: 3.0ms preprocess, 65.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 64.0ms
# Speed: 2.3ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
